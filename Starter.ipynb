# %%
import pandas as pd

# %%
hot = pd.read_csv("billboardHot100_1999-2019.csv")
spot = pd.read_csv("songAttributes_1999-2019.csv")

# %%
hot.head(25)
# Out:
#     Unnamed: 0                       Artists                     Name  \
# 0            1                      Lil Nas,            Old Town Road
# 1            2  Shawn Mendes, Camila Cabello                 Senorita
# 2            3                 Billie Eilish                  Bad Guy
# 3            4                        Khalid                     Talk
# 4            5     Ed Sheeran, Justin Bieber             I Don't Care
# 5            6                Jonas Brothers                   Sucker
# 6            7                        DaBaby                     Suge
# 7            8                         Drake       Money In The Grave
# 8            9                   Chris Brown              No Guidance
# 9           10                   Post Malone                     Wow.
# 10          11                         Lizzo              Truth Hurts
# 11          12         Post Malone, Swae Lee                Sunflower
# ...

# %%
spot.columns
# Out:
# Index(['Unnamed: 0', 'Acousticness', 'Album', 'Artist', 'Danceability',
#        'Duration', 'Energy', 'Explicit', 'Instrumentalness', 'Liveness',
#        'Loudness', 'Mode', 'Name', 'Popularity', 'Speechiness', 'Tempo',
#        'TimeSignature', 'Valence'],
#       dtype='object')

# %%
new_df = hot.merge(spot, left_on=["Artists", "Name"], right_on=["Artist", "Name"])

# %%
new_df.columns
# Out:
# Index(['Unnamed: 0_x', 'Artists', 'Name', 'Weekly.rank', 'Peak.position',
#        'Weeks.on.chart', 'Week', 'Date', 'Genre', 'Writing.Credits', 'Lyrics',
#        'Features', 'Unnamed: 0_y', 'Acousticness', 'Album', 'Artist',
#        'Danceability', 'Duration', 'Energy', 'Explicit', 'Instrumentalness',
#        'Liveness', 'Loudness', 'Mode', 'Popularity', 'Speechiness', 'Tempo',
#        'TimeSignature', 'Valence'],
#       dtype='object')

# %%
new_df.drop(["Unnamed: 0_x", "Unnamed: 0_y"], axis=1, inplace=True)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67161 entries, 0 to 67160
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artists           67161 non-null  object
#  1   Name              67161 non-null  object
#  2   Weekly.rank       67161 non-null  int64
#  3   Peak.position     62933 non-null  float64
#  4   Weeks.on.chart    62933 non-null  float64
#  5   Week              67161 non-null  object
#  6   Date              57451 non-null  object
#  7   Genre             67161 non-null  object
#  8   Writing.Credits   61436 non-null  object
#  9   Lyrics            67161 non-null  object
#  10  Features          10936 non-null  object
#  11  Acousticness      67161 non-null  float64
#  12  Album             67161 non-null  object
#  13  Artist            67161 non-null  object
#  14  Danceability      67161 non-null  float64
#  15  Duration          67161 non-null  int64
# ...

# %%
new_df.drop(["Artist"], axis=1, inplace=True)

# %%
new_df.drop(["Date"], axis=1, inplace=True)

# %%
new_df.drop(["Writing.Credits"], axis=1, inplace=True)

# %%
new_df
# Out:
#                Artists                Name  Weekly.rank  Peak.position  \
# 0       Jonas Brothers              Sucker            6            1.0
# 1       Jonas Brothers              Sucker            6            1.0
# 2       Jonas Brothers              Sucker            4            1.0
# 3       Jonas Brothers              Sucker            5            1.0
# 4       Jonas Brothers              Sucker            5            1.0
# ...                ...                 ...          ...            ...
# 67156       Mark Wills  Wish You Were Here           81           34.0
# 67157       Mark Wills  Wish You Were Here           81           34.0
# 67158      Clay Walker  She's Always Right           85           74.0
# 67159  Collective Soul               Heavy           96           73.0
# 67160  Collective Soul               Heavy           96           73.0
#
#        Weeks.on.chart        Week  \
# 0                17.0  2019-07-06
# 1                16.0  2019-06-29
# ...
